# %%
from alpha_vantage.timeseries import TimeSeries
import pandas as pd
import os

# %%
# Load API key securely
api_key = os.getenv("ALPHA_VANTAGE_API_KEY")
print(api_key)
# Out:
# None

# %%
ts = TimeSeries(key=api_key, output_format="pandas")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 ts = TimeSeries(key=api_key, output_format="pandas")
#
# File ~/miniconda3/envs/stock-market/lib/python3.9/site-packages/alpha_vantage/alphavantage.py:50, in AlphaVantage.__init__(self, key, output_format, treat_info_as_error, indexing_type, proxy, rapidapi)
#      48     key = os.getenv('ALPHAVANTAGE_API_KEY')
#      49 if not key or not isinstance(key, str):
# ---> 50     raise ValueError('The AlphaVantage API key must be provided '
#      51                      'either through the key parameter or '
#      52                      'through the environment variable '
#      53                      'ALPHAVANTAGE_API_KEY. Get a free key '
#      54                      'from the alphavantage website: '
#      55                      'https://www.alphavantage.co/support/#api-key')
#      56 self.headers = {}
#      57 if rapidapi:
#
# ValueError: The AlphaVantage API key must be provided either through the key parameter or through the environment variable ALPHAVANTAGE_API_KEY. Get a free key from the alphavantage website: https://www.alphavantage.co/support/#api-key

# %%
ticker = "TSLA"
data, meta_data = ts.get_daily(symbol=ticker, outputsize="full")

# Show the first 5 rows
print(data.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 ticker = "TSLA"
# ----> 2 data, meta_data = ts.get_daily(symbol=ticker, outputsize="full")
#       4 # Show the first 5 rows
#       5 print(data.head())
#
# NameError: name 'ts' is not defined
